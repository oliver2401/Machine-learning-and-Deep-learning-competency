# %%
import sys
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import numpy as np

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %%
path = Path("datasets/ridership/CTA_-_Ridership_-_Daily_Boarding_Totals.csv")
df = pd.read_csv(path, parse_dates=["service_date"])
df.columns = ["date", "day_type", "bus", "rail", "total"]  # shorter names
df = df.sort_values("date").set_index("date")
df = df.drop("total", axis=1)  # no need for total, it's just bus + rail
df = df.drop_duplicates()  # remove duplicated months (2011-10 and 2014-07)

# %% [markdown]
# Let's look at the first few months of 2019 (note that Pandas treats the range boundaries as inclusive):

# %%
df["2019-03":"2019-05"].plot(grid=True, marker=".", figsize=(8, 3.5))
#save_fig("daily_ridership_plot")
plt.show()

# %%
diff_7 = df[["bus", "rail"]].diff(7)["2019-03":"2019-05"]

fig, axs = plt.subplots(2, 1, sharex=True, figsize=(8, 5))
df.plot(ax=axs[0], legend=False, marker=".")  # original time series
df.shift(7).plot(ax=axs[0], grid=True, legend=False, linestyle=":")  # lagged
diff_7.plot(ax=axs[1], grid=True, marker=".")  # 7-day difference time series
axs[0].set_ylim([170_000, 900_000])  # extra code – beautifies the plot
#save_fig("differencing_plot")  # extra code – saves the figure for the book
plt.show()

# %% [markdown]
# Mean absolute error (MAE), also called mean absolute deviation (MAD):

# %%
diff_7.abs().mean()
# Out:
# bus     43915.608696
# rail    42143.271739
# dtype: float64

# %% [markdown]
# Mean absolute percentage error (MAPE):

# %%
targets = df[["bus", "rail"]]["2019-03":"2019-05"]
(diff_7 / targets).abs().mean()
# Out:
# bus     0.082938
# rail    0.089948
# dtype: float64

# %% [markdown]
# Now let's look at the yearly seasonality and the long-term trends:

# %%
df_monthly.diff(12)[period].plot(grid=True, marker=".", figsize=(8, 3))
#save_fig("yearly_diff_plot")  # extra code – saves the figure for the book
plt.show()

# %% [markdown]
# If running on Colab or Kaggle, install the statsmodels library:

# %%
def to_windows(dataset, length):
    dataset = dataset.window(length, shift=1, drop_remainder=True)
    return dataset.flat_map(lambda window_ds: window_ds.batch(length))

# %% [markdown]
# Before we continue looking at the data, let's split the time series into three periods, for training, validation and testing. We won't look at the test data for now:

# %%
rail_train = df["rail"]["2016-01":"2018-12"] / 1e6
rail_valid = df["rail"]["2019-01":"2019-05"] / 1e6
rail_test = df["rail"]["2019-06":] / 1e6

# %%
seq_length = 56
tf.random.set_seed(42)  # extra code – ensures reproducibility
train_ds = tf.keras.utils.timeseries_dataset_from_array(
    rail_train.to_numpy(),
    targets=rail_train[seq_length:],
    sequence_length=seq_length,
    batch_size=32,
    shuffle=True,
    seed=42
)
valid_ds = tf.keras.utils.timeseries_dataset_from_array(
    rail_valid.to_numpy(),
    targets=rail_valid[seq_length:],
    sequence_length=seq_length,
    batch_size=32
)

# %%
def fit_and_evaluate(model, train_set, valid_set, learning_rate, epochs=500):
    early_stopping_cb = tf.keras.callbacks.EarlyStopping(
        monitor="val_mae", patience=50, restore_best_weights=True)
    opt = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)
    model.compile(loss=tf.keras.losses.Huber(), optimizer=opt, metrics=["mae"])
    history = model.fit(train_set, validation_data=valid_set, epochs=epochs,
                        callbacks=[early_stopping_cb])
    valid_loss, valid_mae = model.evaluate(valid_set)
    return valid_mae * 1e6

# %% [markdown]
# ## Deep RNNs

# %%
tf.random.set_seed(42)  # extra code – ensures reproducibility
deep_model = tf.keras.Sequential([
    tf.keras.layers.SimpleRNN(32, return_sequences=True, input_shape=[None, 1]),
    tf.keras.layers.SimpleRNN(32, return_sequences=True),
    tf.keras.layers.SimpleRNN(32),
    tf.keras.layers.Dense(1)
])

# %%
# extra code – compiles, fits, and evaluates the model, like earlier
fit_and_evaluate(deep_model, train_ds, valid_ds, learning_rate=0.01)
# Out:
# Epoch 1/500
# 33/33 [==============================] - 9s 139ms/step - loss: 0.0137 - mae: 0.1273 - val_loss: 0.0035 - val_mae: 0.0585
# Epoch 2/500
# 33/33 [==============================] - 5s 136ms/step - loss: 0.0053 - mae: 0.0740 - val_loss: 0.0025 - val_mae: 0.0447
# Epoch 3/500
# 33/33 [==============================] - 6s 174ms/step - loss: 0.0040 - mae: 0.0593 - val_loss: 0.0022 - val_mae: 0.0387
# Epoch 4/500
# 33/33 [==============================] - 4s 125ms/step - loss: 0.0038 - mae: 0.0574 - val_loss: 0.0028 - val_mae: 0.0514
# Epoch 5/500
# 33/33 [==============================] - 6s 185ms/step - loss: 0.0037 - mae: 0.0559 - val_loss: 0.0023 - val_mae: 0.0417
# Epoch 6/500
# 33/33 [==============================] - 4s 125ms/step - loss: 0.0037 - mae: 0.0549 - val_loss: 0.0019 - val_mae: 0.0342
# Epoch 7/500
# 33/33 [==============================] - 6s 178ms/step - loss: 0.0035 - mae: 0.0530 - val_loss: 0.0027 - val_mae: 0.0478
# Epoch 8/500
# 33/33 [==============================] - 4s 126ms/step - loss: 0.0034 - mae: 0.0528 - val_loss: 0.0024 - val_mae: 0.0387
# Epoch 9/500
# 33/33 [==============================] - 5s 149ms/step - loss: 0.0033 - mae: 0.0516 - val_loss: 0.0021 - val_mae: 0.0340
# Epoch 10/500
# 33/33 [==============================] - 4s 121ms/step - loss: 0.0031 - mae: 0.0487 - val_loss: 0.0024 - val_mae: 0.0403
# Epoch 11/500
# 33/33 [==============================] - 6s 172ms/step - loss: 0.0032 - mae: 0.0503 - val_loss: 0.0023 - val_mae: 0.0417
# Epoch 12/500
# 33/33 [==============================] - 4s 123ms/step - loss: 0.0031 - mae: 0.0491 - val_loss: 0.0022 - val_mae: 0.0380
# Epoch 13/500
# 33/33 [==============================] - 4s 125ms/step - loss: 0.0032 - mae: 0.0515 - val_loss: 0.0028 - val_mae: 0.0497
# Epoch 14/500
# 33/33 [==============================] - 6s 170ms/step - loss: 0.0034 - mae: 0.0545 - val_loss: 0.0034 - val_mae: 0.0605
# Epoch 15/500
# 33/33 [==============================] - 6s 185ms/step - loss: 0.0033 - mae: 0.0518 - val_loss: 0.0022 - val_mae: 0.0386
# Epoch 16/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0030 - mae: 0.0481 - val_loss: 0.0021 - val_mae: 0.0358
# Epoch 17/500
# 33/33 [==============================] - 6s 168ms/step - loss: 0.0029 - mae: 0.0476 - val_loss: 0.0019 - val_mae: 0.0331
# Epoch 18/500
# 33/33 [==============================] - 6s 174ms/step - loss: 0.0028 - mae: 0.0456 - val_loss: 0.0022 - val_mae: 0.0378
# Epoch 19/500
# 33/33 [==============================] - 4s 125ms/step - loss: 0.0030 - mae: 0.0479 - val_loss: 0.0023 - val_mae: 0.0391
# Epoch 20/500
# 33/33 [==============================] - 4s 132ms/step - loss: 0.0028 - mae: 0.0450 - val_loss: 0.0022 - val_mae: 0.0374
# Epoch 21/500
# 33/33 [==============================] - 6s 174ms/step - loss: 0.0027 - mae: 0.0447 - val_loss: 0.0021 - val_mae: 0.0362
# Epoch 22/500
# 33/33 [==============================] - 4s 130ms/step - loss: 0.0028 - mae: 0.0475 - val_loss: 0.0019 - val_mae: 0.0352
# Epoch 23/500
# 33/33 [==============================] - 6s 181ms/step - loss: 0.0027 - mae: 0.0448 - val_loss: 0.0021 - val_mae: 0.0351
# Epoch 24/500
# 33/33 [==============================] - 4s 129ms/step - loss: 0.0026 - mae: 0.0445 - val_loss: 0.0023 - val_mae: 0.0429
# Epoch 25/500
# 33/33 [==============================] - 6s 174ms/step - loss: 0.0026 - mae: 0.0434 - val_loss: 0.0020 - val_mae: 0.0343
# Epoch 26/500
# 33/33 [==============================] - 4s 129ms/step - loss: 0.0027 - mae: 0.0453 - val_loss: 0.0021 - val_mae: 0.0388
# Epoch 27/500
# 33/33 [==============================] - 6s 175ms/step - loss: 0.0026 - mae: 0.0438 - val_loss: 0.0020 - val_mae: 0.0345
# Epoch 28/500
# 33/33 [==============================] - 4s 128ms/step - loss: 0.0027 - mae: 0.0474 - val_loss: 0.0021 - val_mae: 0.0391
# Epoch 29/500
# 33/33 [==============================] - 4s 129ms/step - loss: 0.0027 - mae: 0.0455 - val_loss: 0.0020 - val_mae: 0.0343
# Epoch 30/500
# 33/33 [==============================] - 6s 169ms/step - loss: 0.0026 - mae: 0.0429 - val_loss: 0.0020 - val_mae: 0.0365
# Epoch 31/500
# 33/33 [==============================] - 5s 159ms/step - loss: 0.0028 - mae: 0.0467 - val_loss: 0.0020 - val_mae: 0.0365
# Epoch 32/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0025 - mae: 0.0432 - val_loss: 0.0020 - val_mae: 0.0361
# Epoch 33/500
# 33/33 [==============================] - 6s 175ms/step - loss: 0.0025 - mae: 0.0425 - val_loss: 0.0018 - val_mae: 0.0364
# Epoch 34/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0026 - mae: 0.0445 - val_loss: 0.0019 - val_mae: 0.0351
# Epoch 35/500
# 33/33 [==============================] - 6s 168ms/step - loss: 0.0025 - mae: 0.0432 - val_loss: 0.0019 - val_mae: 0.0373
# Epoch 36/500
# 33/33 [==============================] - 4s 128ms/step - loss: 0.0025 - mae: 0.0438 - val_loss: 0.0019 - val_mae: 0.0372
# Epoch 37/500
# 33/33 [==============================] - 7s 207ms/step - loss: 0.0025 - mae: 0.0431 - val_loss: 0.0020 - val_mae: 0.0395
# Epoch 38/500
# 33/33 [==============================] - 4s 128ms/step - loss: 0.0025 - mae: 0.0430 - val_loss: 0.0018 - val_mae: 0.0349
# Epoch 39/500
# 33/33 [==============================] - 4s 132ms/step - loss: 0.0024 - mae: 0.0414 - val_loss: 0.0019 - val_mae: 0.0349
# Epoch 40/500
# 33/33 [==============================] - 5s 131ms/step - loss: 0.0024 - mae: 0.0425 - val_loss: 0.0019 - val_mae: 0.0363
# Epoch 41/500
# 33/33 [==============================] - 4s 125ms/step - loss: 0.0025 - mae: 0.0434 - val_loss: 0.0018 - val_mae: 0.0351
# Epoch 42/500
# 33/33 [==============================] - 6s 170ms/step - loss: 0.0024 - mae: 0.0417 - val_loss: 0.0019 - val_mae: 0.0350
# Epoch 43/500
# 33/33 [==============================] - 4s 128ms/step - loss: 0.0025 - mae: 0.0425 - val_loss: 0.0021 - val_mae: 0.0396
# Epoch 44/500
# 33/33 [==============================] - 7s 205ms/step - loss: 0.0024 - mae: 0.0419 - val_loss: 0.0022 - val_mae: 0.0447
# Epoch 45/500
# 33/33 [==============================] - 5s 135ms/step - loss: 0.0025 - mae: 0.0435 - val_loss: 0.0020 - val_mae: 0.0412
# Epoch 46/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0025 - mae: 0.0453 - val_loss: 0.0019 - val_mae: 0.0375
# Epoch 47/500
# 33/33 [==============================] - 6s 170ms/step - loss: 0.0023 - mae: 0.0407 - val_loss: 0.0018 - val_mae: 0.0347
# Epoch 48/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0024 - mae: 0.0414 - val_loss: 0.0018 - val_mae: 0.0337
# Epoch 49/500
# 33/33 [==============================] - 6s 168ms/step - loss: 0.0023 - mae: 0.0406 - val_loss: 0.0017 - val_mae: 0.0325
# Epoch 50/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0024 - mae: 0.0420 - val_loss: 0.0019 - val_mae: 0.0376
# Epoch 51/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0023 - mae: 0.0402 - val_loss: 0.0018 - val_mae: 0.0344
# Epoch 52/500
# 33/33 [==============================] - 6s 172ms/step - loss: 0.0023 - mae: 0.0419 - val_loss: 0.0018 - val_mae: 0.0346
# Epoch 53/500
# 33/33 [==============================] - 4s 128ms/step - loss: 0.0025 - mae: 0.0436 - val_loss: 0.0018 - val_mae: 0.0331
# Epoch 54/500
# 33/33 [==============================] - 4s 126ms/step - loss: 0.0023 - mae: 0.0418 - val_loss: 0.0019 - val_mae: 0.0387
# Epoch 55/500
# 33/33 [==============================] - 5s 151ms/step - loss: 0.0024 - mae: 0.0429 - val_loss: 0.0018 - val_mae: 0.0351
# Epoch 56/500
# 33/33 [==============================] - 4s 130ms/step - loss: 0.0024 - mae: 0.0423 - val_loss: 0.0019 - val_mae: 0.0372
# Epoch 57/500
# 33/33 [==============================] - 6s 176ms/step - loss: 0.0024 - mae: 0.0420 - val_loss: 0.0019 - val_mae: 0.0383
# Epoch 58/500
# 33/33 [==============================] - 4s 130ms/step - loss: 0.0022 - mae: 0.0404 - val_loss: 0.0019 - val_mae: 0.0372
# Epoch 59/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0023 - mae: 0.0410 - val_loss: 0.0019 - val_mae: 0.0348
# Epoch 60/500
# 33/33 [==============================] - 6s 178ms/step - loss: 0.0023 - mae: 0.0401 - val_loss: 0.0018 - val_mae: 0.0372
# Epoch 61/500
# 33/33 [==============================] - 4s 131ms/step - loss: 0.0022 - mae: 0.0399 - val_loss: 0.0017 - val_mae: 0.0339
# Epoch 62/500
# 33/33 [==============================] - 6s 168ms/step - loss: 0.0023 - mae: 0.0396 - val_loss: 0.0019 - val_mae: 0.0372
# Epoch 63/500
# 33/33 [==============================] - 4s 126ms/step - loss: 0.0023 - mae: 0.0409 - val_loss: 0.0019 - val_mae: 0.0359
# Epoch 64/500
# 33/33 [==============================] - 7s 210ms/step - loss: 0.0023 - mae: 0.0402 - val_loss: 0.0018 - val_mae: 0.0331
# Epoch 65/500
# 33/33 [==============================] - 6s 175ms/step - loss: 0.0025 - mae: 0.0454 - val_loss: 0.0026 - val_mae: 0.0536
# Epoch 66/500
# 33/33 [==============================] - 4s 129ms/step - loss: 0.0022 - mae: 0.0405 - val_loss: 0.0018 - val_mae: 0.0366
# Epoch 67/500
# 33/33 [==============================] - 6s 176ms/step - loss: 0.0022 - mae: 0.0397 - val_loss: 0.0018 - val_mae: 0.0332
# Epoch 68/500
# 33/33 [==============================] - 4s 131ms/step - loss: 0.0022 - mae: 0.0384 - val_loss: 0.0018 - val_mae: 0.0334
# Epoch 69/500
# 33/33 [==============================] - 5s 145ms/step - loss: 0.0023 - mae: 0.0407 - val_loss: 0.0025 - val_mae: 0.0467
# Epoch 70/500
# 33/33 [==============================] - 5s 149ms/step - loss: 0.0026 - mae: 0.0469 - val_loss: 0.0017 - val_mae: 0.0338
# Epoch 71/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0024 - mae: 0.0421 - val_loss: 0.0022 - val_mae: 0.0408
# Epoch 72/500
# 33/33 [==============================] - 6s 173ms/step - loss: 0.0026 - mae: 0.0465 - val_loss: 0.0022 - val_mae: 0.0434
# Epoch 73/500
# 33/33 [==============================] - 4s 128ms/step - loss: 0.0026 - mae: 0.0468 - val_loss: 0.0018 - val_mae: 0.0371
# Epoch 74/500
# 33/33 [==============================] - 4s 131ms/step - loss: 0.0022 - mae: 0.0394 - val_loss: 0.0019 - val_mae: 0.0395
# Epoch 75/500
# 33/33 [==============================] - 5s 145ms/step - loss: 0.0025 - mae: 0.0450 - val_loss: 0.0024 - val_mae: 0.0495
# Epoch 76/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0022 - mae: 0.0401 - val_loss: 0.0017 - val_mae: 0.0342
# Epoch 77/500
# 33/33 [==============================] - 6s 178ms/step - loss: 0.0024 - mae: 0.0428 - val_loss: 0.0018 - val_mae: 0.0330
# Epoch 78/500
# 33/33 [==============================] - 5s 147ms/step - loss: 0.0023 - mae: 0.0403 - val_loss: 0.0019 - val_mae: 0.0407
# Epoch 79/500
# 33/33 [==============================] - 5s 153ms/step - loss: 0.0022 - mae: 0.0387 - val_loss: 0.0018 - val_mae: 0.0355
# Epoch 80/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0022 - mae: 0.0393 - val_loss: 0.0018 - val_mae: 0.0360
# Epoch 81/500
# 33/33 [==============================] - 6s 174ms/step - loss: 0.0023 - mae: 0.0422 - val_loss: 0.0017 - val_mae: 0.0337
# Epoch 82/500
# 33/33 [==============================] - 4s 128ms/step - loss: 0.0022 - mae: 0.0395 - val_loss: 0.0017 - val_mae: 0.0328
# Epoch 83/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0022 - mae: 0.0395 - val_loss: 0.0021 - val_mae: 0.0435
# Epoch 84/500
# 33/33 [==============================] - 5s 157ms/step - loss: 0.0022 - mae: 0.0410 - val_loss: 0.0019 - val_mae: 0.0391
# Epoch 85/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0021 - mae: 0.0383 - val_loss: 0.0019 - val_mae: 0.0376
# Epoch 86/500
# 33/33 [==============================] - 6s 178ms/step - loss: 0.0022 - mae: 0.0402 - val_loss: 0.0017 - val_mae: 0.0343
# Epoch 87/500
# 33/33 [==============================] - 7s 214ms/step - loss: 0.0022 - mae: 0.0393 - val_loss: 0.0020 - val_mae: 0.0376
# Epoch 88/500
# 33/33 [==============================] - 4s 129ms/step - loss: 0.0025 - mae: 0.0448 - val_loss: 0.0018 - val_mae: 0.0365
# Epoch 89/500
# 33/33 [==============================] - 7s 225ms/step - loss: 0.0021 - mae: 0.0384 - val_loss: 0.0017 - val_mae: 0.0324
# Epoch 90/500
# 33/33 [==============================] - 4s 128ms/step - loss: 0.0024 - mae: 0.0444 - val_loss: 0.0018 - val_mae: 0.0343
# Epoch 91/500
# 33/33 [==============================] - 5s 148ms/step - loss: 0.0025 - mae: 0.0455 - val_loss: 0.0021 - val_mae: 0.0396
# Epoch 92/500
# 33/33 [==============================] - 5s 149ms/step - loss: 0.0022 - mae: 0.0407 - val_loss: 0.0018 - val_mae: 0.0364
# Epoch 93/500
# 33/33 [==============================] - 4s 134ms/step - loss: 0.0022 - mae: 0.0398 - val_loss: 0.0019 - val_mae: 0.0393
# Epoch 94/500
# 33/33 [==============================] - 6s 185ms/step - loss: 0.0023 - mae: 0.0414 - val_loss: 0.0017 - val_mae: 0.0325
# Epoch 95/500
# 33/33 [==============================] - 5s 139ms/step - loss: 0.0022 - mae: 0.0398 - val_loss: 0.0026 - val_mae: 0.0553
# Epoch 96/500
# 33/33 [==============================] - 6s 175ms/step - loss: 0.0022 - mae: 0.0406 - val_loss: 0.0018 - val_mae: 0.0352
# Epoch 97/500
# 33/33 [==============================] - 4s 131ms/step - loss: 0.0022 - mae: 0.0408 - val_loss: 0.0017 - val_mae: 0.0355
# Epoch 98/500
# 33/33 [==============================] - 6s 183ms/step - loss: 0.0021 - mae: 0.0383 - val_loss: 0.0018 - val_mae: 0.0365
# Epoch 99/500
# 33/33 [==============================] - 4s 130ms/step - loss: 0.0022 - mae: 0.0397 - val_loss: 0.0021 - val_mae: 0.0453
# Epoch 100/500
# 33/33 [==============================] - 5s 145ms/step - loss: 0.0021 - mae: 0.0405 - val_loss: 0.0017 - val_mae: 0.0334
# Epoch 101/500
# 33/33 [==============================] - 5s 146ms/step - loss: 0.0022 - mae: 0.0407 - val_loss: 0.0019 - val_mae: 0.0374
# Epoch 102/500
# 33/33 [==============================] - 4s 129ms/step - loss: 0.0022 - mae: 0.0394 - val_loss: 0.0018 - val_mae: 0.0358
# Epoch 103/500
# 33/33 [==============================] - 6s 177ms/step - loss: 0.0021 - mae: 0.0394 - val_loss: 0.0018 - val_mae: 0.0352
# Epoch 104/500
# 33/33 [==============================] - 4s 129ms/step - loss: 0.0022 - mae: 0.0404 - val_loss: 0.0018 - val_mae: 0.0334
# Epoch 105/500
# 33/33 [==============================] - 6s 172ms/step - loss: 0.0023 - mae: 0.0439 - val_loss: 0.0019 - val_mae: 0.0379
# Epoch 106/500
# 33/33 [==============================] - 4s 128ms/step - loss: 0.0021 - mae: 0.0380 - val_loss: 0.0017 - val_mae: 0.0352
# Epoch 107/500
# 33/33 [==============================] - 7s 223ms/step - loss: 0.0021 - mae: 0.0390 - val_loss: 0.0017 - val_mae: 0.0328
# Epoch 108/500
# 33/33 [==============================] - 4s 129ms/step - loss: 0.0021 - mae: 0.0397 - val_loss: 0.0017 - val_mae: 0.0339
# Epoch 109/500
# 33/33 [==============================] - 4s 129ms/step - loss: 0.0021 - mae: 0.0375 - val_loss: 0.0017 - val_mae: 0.0333
# Epoch 110/500
# 33/33 [==============================] - 5s 149ms/step - loss: 0.0022 - mae: 0.0408 - val_loss: 0.0017 - val_mae: 0.0344
# Epoch 111/500
# 33/33 [==============================] - 4s 130ms/step - loss: 0.0022 - mae: 0.0387 - val_loss: 0.0019 - val_mae: 0.0410
# Epoch 112/500
# 33/33 [==============================] - 6s 175ms/step - loss: 0.0021 - mae: 0.0394 - val_loss: 0.0017 - val_mae: 0.0321
# Epoch 113/500
# 33/33 [==============================] - 4s 133ms/step - loss: 0.0022 - mae: 0.0399 - val_loss: 0.0017 - val_mae: 0.0356
# Epoch 114/500
# 33/33 [==============================] - 7s 200ms/step - loss: 0.0023 - mae: 0.0427 - val_loss: 0.0019 - val_mae: 0.0388
# Epoch 115/500
# 33/33 [==============================] - 6s 178ms/step - loss: 0.0021 - mae: 0.0403 - val_loss: 0.0018 - val_mae: 0.0356
# Epoch 116/500
# 33/33 [==============================] - 5s 139ms/step - loss: 0.0022 - mae: 0.0396 - val_loss: 0.0018 - val_mae: 0.0380
# Epoch 117/500
# 33/33 [==============================] - 5s 150ms/step - loss: 0.0021 - mae: 0.0391 - val_loss: 0.0018 - val_mae: 0.0354
# Epoch 118/500
# 33/33 [==============================] - 4s 132ms/step - loss: 0.0022 - mae: 0.0408 - val_loss: 0.0019 - val_mae: 0.0360
# Epoch 119/500
# 33/33 [==============================] - 6s 174ms/step - loss: 0.0022 - mae: 0.0405 - val_loss: 0.0018 - val_mae: 0.0362
# Epoch 120/500
# 33/33 [==============================] - 5s 141ms/step - loss: 0.0020 - mae: 0.0382 - val_loss: 0.0017 - val_mae: 0.0347
# Epoch 121/500
# 33/33 [==============================] - 5s 156ms/step - loss: 0.0022 - mae: 0.0406 - val_loss: 0.0018 - val_mae: 0.0375
# Epoch 122/500
# 33/33 [==============================] - 6s 175ms/step - loss: 0.0022 - mae: 0.0407 - val_loss: 0.0017 - val_mae: 0.0339
# Epoch 123/500
# 33/33 [==============================] - 4s 131ms/step - loss: 0.0021 - mae: 0.0379 - val_loss: 0.0017 - val_mae: 0.0348
# Epoch 124/500
# 33/33 [==============================] - 4s 132ms/step - loss: 0.0020 - mae: 0.0374 - val_loss: 0.0018 - val_mae: 0.0344
# Epoch 125/500
# 33/33 [==============================] - 7s 200ms/step - loss: 0.0025 - mae: 0.0456 - val_loss: 0.0019 - val_mae: 0.0386
# Epoch 126/500
# 33/33 [==============================] - 6s 175ms/step - loss: 0.0022 - mae: 0.0409 - val_loss: 0.0018 - val_mae: 0.0360
# Epoch 127/500
# 33/33 [==============================] - 4s 132ms/step - loss: 0.0020 - mae: 0.0388 - val_loss: 0.0022 - val_mae: 0.0441
# Epoch 128/500
# 33/33 [==============================] - 5s 162ms/step - loss: 0.0024 - mae: 0.0441 - val_loss: 0.0019 - val_mae: 0.0395
# Epoch 129/500
# 33/33 [==============================] - 4s 128ms/step - loss: 0.0021 - mae: 0.0407 - val_loss: 0.0017 - val_mae: 0.0364
# Epoch 130/500
# 33/33 [==============================] - 6s 173ms/step - loss: 0.0021 - mae: 0.0402 - val_loss: 0.0017 - val_mae: 0.0358
# Epoch 131/500
# 33/33 [==============================] - 4s 129ms/step - loss: 0.0021 - mae: 0.0409 - val_loss: 0.0021 - val_mae: 0.0409
# Epoch 132/500
# 33/33 [==============================] - 5s 144ms/step - loss: 0.0023 - mae: 0.0420 - val_loss: 0.0017 - val_mae: 0.0347
# Epoch 133/500
# 33/33 [==============================] - 5s 145ms/step - loss: 0.0023 - mae: 0.0440 - val_loss: 0.0018 - val_mae: 0.0354
# Epoch 134/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0021 - mae: 0.0386 - val_loss: 0.0018 - val_mae: 0.0358
# Epoch 135/500
# 33/33 [==============================] - 6s 175ms/step - loss: 0.0020 - mae: 0.0388 - val_loss: 0.0017 - val_mae: 0.0333
# Epoch 136/500
# 33/33 [==============================] - 4s 132ms/step - loss: 0.0020 - mae: 0.0383 - val_loss: 0.0018 - val_mae: 0.0384
# Epoch 137/500
# 33/33 [==============================] - 7s 205ms/step - loss: 0.0020 - mae: 0.0372 - val_loss: 0.0016 - val_mae: 0.0344
# Epoch 138/500
# 33/33 [==============================] - 4s 130ms/step - loss: 0.0020 - mae: 0.0389 - val_loss: 0.0017 - val_mae: 0.0347
# Epoch 139/500
# 33/33 [==============================] - 4s 132ms/step - loss: 0.0020 - mae: 0.0388 - val_loss: 0.0017 - val_mae: 0.0360
# Epoch 140/500
# 33/33 [==============================] - 6s 178ms/step - loss: 0.0020 - mae: 0.0382 - val_loss: 0.0025 - val_mae: 0.0478
# Epoch 141/500
# 33/33 [==============================] - 4s 130ms/step - loss: 0.0021 - mae: 0.0419 - val_loss: 0.0017 - val_mae: 0.0334
# Epoch 142/500
# 33/33 [==============================] - 5s 149ms/step - loss: 0.0021 - mae: 0.0389 - val_loss: 0.0018 - val_mae: 0.0358
# Epoch 143/500
# 33/33 [==============================] - 5s 150ms/step - loss: 0.0021 - mae: 0.0397 - val_loss: 0.0019 - val_mae: 0.0407
# Epoch 144/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0021 - mae: 0.0406 - val_loss: 0.0018 - val_mae: 0.0377
# Epoch 145/500
# 33/33 [==============================] - 6s 176ms/step - loss: 0.0021 - mae: 0.0390 - val_loss: 0.0018 - val_mae: 0.0361
# Epoch 146/500
# 33/33 [==============================] - 4s 128ms/step - loss: 0.0022 - mae: 0.0424 - val_loss: 0.0023 - val_mae: 0.0460
# Epoch 147/500
# 33/33 [==============================] - 6s 187ms/step - loss: 0.0022 - mae: 0.0417 - val_loss: 0.0017 - val_mae: 0.0358
# Epoch 148/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0020 - mae: 0.0382 - val_loss: 0.0018 - val_mae: 0.0372
# Epoch 149/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0019 - mae: 0.0363 - val_loss: 0.0017 - val_mae: 0.0337
# Epoch 150/500
# 33/33 [==============================] - 6s 169ms/step - loss: 0.0020 - mae: 0.0376 - val_loss: 0.0018 - val_mae: 0.0384
# Epoch 151/500
# 33/33 [==============================] - 4s 127ms/step - loss: 0.0021 - mae: 0.0402 - val_loss: 0.0017 - val_mae: 0.0353
# Epoch 152/500
# 33/33 [==============================] - 6s 168ms/step - loss: 0.0019 - mae: 0.0367 - val_loss: 0.0018 - val_mae: 0.0380
# Epoch 153/500
# 33/33 [==============================] - 4s 132ms/step - loss: 0.0020 - mae: 0.0392 - val_loss: 0.0017 - val_mae: 0.0360
# Epoch 154/500
# 33/33 [==============================] - 6s 185ms/step - loss: 0.0021 - mae: 0.0390 - val_loss: 0.0018 - val_mae: 0.0370
# Epoch 155/500
# 33/33 [==============================] - 4s 133ms/step - loss: 0.0020 - mae: 0.0380 - val_loss: 0.0017 - val_mae: 0.0353
# Epoch 156/500
# 33/33 [==============================] - 6s 179ms/step - loss: 0.0021 - mae: 0.0397 - val_loss: 0.0017 - val_mae: 0.0358
# Epoch 157/500
# 33/33 [==============================] - 4s 134ms/step - loss: 0.0022 - mae: 0.0438 - val_loss: 0.0016 - val_mae: 0.0333
# Epoch 158/500
# 33/33 [==============================] - 4s 134ms/step - loss: 0.0021 - mae: 0.0404 - val_loss: 0.0021 - val_mae: 0.0460
# Epoch 159/500
# 33/33 [==============================] - 6s 177ms/step - loss: 0.0021 - mae: 0.0412 - val_loss: 0.0020 - val_mae: 0.0450
# Epoch 160/500
# 33/33 [==============================] - 6s 173ms/step - loss: 0.0020 - mae: 0.0389 - val_loss: 0.0018 - val_mae: 0.0387
# Epoch 161/500
# 33/33 [==============================] - 4s 130ms/step - loss: 0.0020 - mae: 0.0395 - val_loss: 0.0018 - val_mae: 0.0375
# Epoch 162/500
# 33/33 [==============================] - 4s 133ms/step - loss: 0.0020 - mae: 0.0379 - val_loss: 0.0017 - val_mae: 0.0368
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0017 - mae: 0.0321
# 32057.35981464386

# %%
X = rail_valid.to_numpy()[np.newaxis, :seq_length, np.newaxis]
for step_ahead in range(14):
    y_pred_one = deep_model.predict(X)
    X = np.concatenate([X, y_pred_one.reshape(1, 1, 1)], axis=1)
# Out:
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step

# %%
Y_pred = pd.Series(X[0, -14:, 0],
                   index=pd.date_range("2019-02-26", "2019-03-11"))

fig, ax = plt.subplots(figsize=(8, 3.5))
(rail_valid * 1e6)["2019-02-01":"2019-03-11"].plot(
    label="True", marker=".", ax=ax)
(Y_pred * 1e6).plot(
    label="Predictions", grid=True, marker="x", color="r", ax=ax)
ax.vlines("2019-02-25", 0, 1e6, color="k", linestyle="--", label="Today")
ax.set_ylim([200_000, 800_000])
plt.legend(loc="center left")
#save_fig("forecast_ahead_plot")
plt.show()
